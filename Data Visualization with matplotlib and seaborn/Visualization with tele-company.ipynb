# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('D:\Programming for Data Science2\Dataset\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.loc[200:205, ['TotalCharges', 'Churn']]
# Out:
#     TotalCharges Churn
# 200      2681.15    No
# 201       1112.3    No
# 202       7405.5    No
# 203      1033.95    No
# 204      2958.95    No
# 205      2684.85    No

# %%
df1 = df.iloc[200:206, [-1, -2]]

# %%
df1['TotalCharges']=='7405.5'
# Out:
# 200    False
# 201    False
# 202     True
# 203    False
# 204    False
# 205    False
# Name: TotalCharges, dtype: bool

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
df['TotalCharges']= pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.to_csv('WA_Fn-UseC_-Telco-Customer-ChurnFinall.csv', index=False)

# %%
df3 = pd.read_csv('WA_Fn-UseC_-Telco-Customer-ChurnFinall.csv')

# %%
df3
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df3.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
# df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df[df['TotalCharges'].isnull()].to_csv('missingdata.csv', index=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Function drop missing : dropna

# %%
df[df['TotalCharges'].isnull()]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.to_csv('Finall_telecom_company.csv', index=False)

# %%
df = pd.read_csv('Finall_telecom_company.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 6), dpi = 300)

sns.countplot( x = df['gender'], hue = df['Churn'], ax = ax[0])
ax[0].set_title('Gender vs Churn ')

sns.countplot(x = df['SeniorCitizen'], hue = df['Churn'], ax = ax[1])
ax[1].set_yticks(np.arange(0, 5000, 500))
ax[1].set_title('SeniorCitizen vs Churn')

# plt.savefig('Photo1.png', dpi = 1000)
plt.show()

# %%
plt.xlabel()

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6352
# No      680
# Name: count, dtype: int64

# %%
df['InternetService'].value_counts().values
# Out:
# array([3096, 2416, 1520], dtype=int64)

# %%
df['InternetService'].value_counts().index
# Out:
# Index(['Fiber optic', 'DSL', 'No'], dtype='object', name='InternetService')

# %%
fig, ax = plt.subplots( figsize = (10, 4), dpi = 300)

sns.barplot(x =df['InternetService'].value_counts().index ,
            y=df['InternetService'].value_counts().values,
            width=0.4 )
ax.set_title('InternetService')
ax.set_yticks(np.arange(0, 3300, 300))
# ax.set_xticks()
ax.spines[['top',
           'right',
           'left'
          ]].set_visible(False)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 4), dpi = 300)
sns.countplot(data = df, x = df['PhoneService'], hue = df['Churn'], ax = ax[0])
sns.countplot(x = df['InternetService'], hue = df['Churn'], ax = ax[1])

plt.show()

# %%
df['tenure'].value_counts()
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: count, Length: 72, dtype: int64

# %%
fig, ax = plt.subplots( figsize = (16, 4), dpi = 300)

sns.barplot(x =df['tenure'].value_counts().index ,
            y=df['tenure'].value_counts().values,
            width=0.4 )
# ax.set_title('InternetService')
# ax.set_yticks(np.arange(0, 3300, 300))
# ax.set_xticks()
ax.spines[['top',
           'right',
           'left'
          ]].set_visible(False)
plt.show()

# %%
fig, ax = plt.subplots( figsize = (16, 4), dpi = 300)
sns.lineplot(x =df['tenure'].value_counts().index ,
            y=df['tenure'].value_counts().values)
ax.set_xticks(np.arange(1, 74, 2))
plt.show()

# %%
fig, ax = plt.subplots( figsize = (16, 4), dpi = 300)
sns.histplot(x = df['tenure'], bins =7)
ax.set_xticks(np.arange(1, 74, 2))
plt.show()

# %%
fig, ax = plt.subplots( figsize = (16, 4), dpi = 300)
sns.scatterplot(x =df['tenure'].value_counts().index ,
            y=df['tenure'].value_counts().values)
ax.set_xticks(np.arange(1, 74, 2))
ax.grid()
plt.show()

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.90     44
# 19.95     44
# 19.85     44
# 19.65     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1584, dtype: int64

# %%
fig, ax = plt.subplots( figsize = (12, 4), dpi = 300)
sns.histplot(df['MonthlyCharges'] , bins = 30, label = 'Distribution of MonthlyCharges', color = 'green')
sns.histplot(df[df['Churn']=='Yes']['MonthlyCharges'], bins = 30, label ='Churn Yes vs MonthlyCharges', color = 'r')
sns.histplot(df[df['Churn']=='No']['MonthlyCharges'], bins = 30, label ='Churn No vs MonthlyCharges', color = 'b')
ax.legend()
ax.set_xticks(np.arange(18, 130, 5))
ax.set_yticks(np.arange(0, 1300, 100))
ax.set_ylabel('Frequency')
ax.set_title('')
ax.spines[['top',
           'right',
           'left'
          ]].set_visible(False)
plt.show()

# %%
a = b = 2

# %%
b
# Out:
# 2

# %%
a
# Out:
# 2

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 10))
sns.histplot(df['TotalCharges'], 
             label = ' Distribution of TotalCharges', bins = 40, ax = ax[0])
sns.histplot(df[df['Churn']=='No']['TotalCharges'] ,
             label = 'Churn No with TotalCharge', color = 'b',bins = 40, ax =ax[0])
# ax[0].set_xticks(np.arange(0, 9000, 500))
# ax[0].legend()

sns.histplot(df['TotalCharges'], 
             label = ' Distribution of TotalCharges', bins = 40, ax = ax[1])
sns.histplot(df[df['Churn']=='Yes']['TotalCharges'] , 
             label = 'Churn Yes with TotalCharge', bins = 40, color = 'r', ax=ax[1])
# ax[1].legend(loc = 2)
for i in ax:
    i.legend()
    
plt.tight_layout()

# ax[0].spines[['top',
#            'right',
#            'left'
#     ]].set_visible(False)
# ax[1].spines[['top',
#            'right',
#            'left'
#           ]].set_visible(False)
for a in ax:
    a.spines[['top',
           'right',
           'left'
          ]].set_visible(False)
plt.show()

# %%
fig, ax = plt.subplots( figsize = (12, 4), dpi = 300)

sns.histplot(df['MonthlyCharges'] , bins = 30)
ax.set_xticks(np.arange(18, 130, 5))
ax.spines[['top',
           'right',
           'left'
          ]].set_visible(False)
plt.show()

# %% [markdown]
# <!-- <img src="Photo1.png" alt="Photo1_testing" width="100%" style="display: block; margin: 0 auto;"> -->

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5890
# 1    1142
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64

# %%
df['Churn']

# %%
fig, ax = plt.subplots(1, 3, figsize = (16, 4))
sns.histplot(df['TotalCharges'], label = ' Distribution of TotalCharges', ax = ax[0])
sns.histplot(df[df['Churn']=='Yes']['TotalCharges'] , label = 'Churn Yes with TotalCharge', ax = ax[1], color = 'r')
sns.histplot(df[df['Churn']=='No']['TotalCharges'] , label = 'Churn Yes with TotalCharge', color = 'b', ax = ax[2])
# ax.set_xticks(np.arange(0, 9000, 500))
ax[1].legend()
plt.show()

# %%
df_totalcharges0_10000 = df[(df['TotalCharges']>=0) & (df['TotalCharges']<=1000)].reset_index().drop(columns='index')

# %%
df_totalcharges0_10000.iloc[0:1600]

# %%
df[df['TotalCharges']==0]

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 4))
sns.countplot(data = df, x = df['gender'], hue = df['Churn'], ax = ax[0])
sns.countplot(x = df['SeniorCitizen'], hue = df['Churn'], ax = ax[1])

plt.show()

# %%
df.columns

# %%
df[['PhoneService', 'InternetService']]

# %%
df[['OnlineSecurity', 'OnlineBackup']]

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 4))
sns.countplot(data = df, x = df['Partner'], hue = df['Churn'], ax = ax[0])
sns.countplot(x = df['Dependents'], hue = df['Churn'], ax = ax[1])

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 4), dpi = 300)
sns.countplot(data = df, x = df['PhoneService'], hue = df['Churn'], ax = ax[0])
sns.countplot(x = df['InternetService'], hue = df['Churn'], ax = ax[1])

plt.show()

# %%
df.columns
