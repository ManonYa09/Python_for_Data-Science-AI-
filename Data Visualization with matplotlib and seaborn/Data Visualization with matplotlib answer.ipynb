# %% [markdown]
# <h1 style="font-family:verdana;"> <center>🏦Bank🏦 Churn Dataset🦥:</center> </h1>

# %% [markdown]
# # Table of Contents :
# * [1. About Dataset](#section1)
# * [2. Exploring Dataset](#section2)
# * [3. Data Exploration](#section3)
#   - [Feature Description](#section31)
#   - [Null Value Distribution](#section32)
#   - [Data Cleaning](#section33)

# %% [markdown]
# <a id="section1"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#222222;
#             overflow:hidden;
#             font-weight:700">About <span style='color:#CDA63A'>|</span>Dataset</div>
#
# ![Bank](https://images.pexels.com/photos/351264/pexels-photo-351264.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500)
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em"> We are given the dataset about bank information of around 10000 customers and also given if they have churned or not.</p>

# %% [markdown]
# <a id="section2"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#222222;
#             overflow:hidden;
#             font-weight:700">1 <span style='color:#CDA63A'>|</span>Exploring The Dataset</div>

# %%
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
#Importing all essential libraries
import numpy as np , pandas as pd, seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="section3"></a>
# ###  Data Description :

# %% [markdown]
# <a id="section31"></a>
# <div style="font-size:15px; font-family:verdana;"><h3 style="font-family:verdana;">Feature Description:</h3>
#
# <ol>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Customer ID</code> - Unique ID given to identify a particular customer.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Credit Score</code> - It is the score which determines the creditworthiness of a customer.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Country</code> - The country where customer lives.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Gender</code> - The Sex of customer.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Age</code> - The age of customer.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Tenure</code> - Number of years the customer has Bank Account in that Bank.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Balance</code> - Amount of money present in customer's bank.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Products Number</code> - Number of Products from that Bank.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Credit Card</code> - Does the customer own a credit card of that Bank.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Active Member</code> - Whether the customer is an active member of that Bank.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Estimated Salary</code> - Total Income of the Customer.</li>
#     <li style="font-family:verdana;"><code style="font-family:verdana;">Churn</code> - Churn (Loss of existing customers) of the Bank.</li>
# </ol>
# </div>

# %%
df = pd.read_csv('Bank Customer Churn Prediction.csv')

# %% [markdown]
# 1. Display index [12, 34, 45, 53, 1000, 2000] of The Dataset using iloc or loc function.

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
type('1')
# Out:
# str

# %%
df.iloc[[12, 34, 45, 53, 1000, 2000]]
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 12       15632264           476   France  Female   34      10       0.00
# 34       15732963           722    Spain  Female   29       9       0.00
# 45       15754849           776  Germany  Female   32       4  109421.13
# 53       15702298           655  Germany    Male   41       8  125561.97
# 1000     15691111           648  Germany  Female   42       8  121980.56
# 2000     15613656           842   France    Male   58       1   63492.94
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 12                  2            1              0          26260.98      0
# 34                  2            1              1         142033.07      0
# 45                  2            1              1         126517.46      0
# 53                  1            0              0         164040.94      1
# 1000                2            1              0           4027.02      0
# 2000                1            1              1          83172.19      0

# %%
df['credit_card'].replace({1:'Yes',
                          0:'No'}, inplace=True)

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number credit_card active_member  estimated_salary churn
# 0                1         Yes           Yes         101348.88   Yes
# 1                1          No           Yes         112542.58    No
# 2                3         Yes            No         113931.57   Yes
# 3                2          No            No          93826.63    No
# 4                1         Yes           Yes          79084.10    No

# %%
df['active_member'].replace({1:'Yes',
                          0:'No'}, inplace=True)

# %%
df['churn'].replace({1:'Yes',
                        0:'No'}, inplace=True)

# %% [markdown]
# 2. a. Check Datatype of each columns
#
#     b. How many rows and columns are there in our Dataset?

# %%
# a.
df.dtypes
# Out:
# customer_id           int64
# credit_score          int64
# country              object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# products_number       int64
# credit_card          object
# active_member        object
# estimated_salary    float64
# churn                object
# dtype: object

# %%
# b.
df.shape
# Out:
# (10000, 12)

# %%
df.shape[0]
# Out:
# 10000

# %%
df.shape[1]
# Out:
# 12

# %%
a, b = df.shape

# %%
b
# Out:
# 12

# %% [markdown]
# 3. Drop column `customer_id` using `drop` function

# %%
#3 
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.drop(columns='customer_id', inplace=True)

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#   credit_card active_member  estimated_salary churn
# 0         Yes           Yes         101348.88   Yes
# 1          No           Yes         112542.58    No
# 2         Yes            No         113931.57   Yes
# 3          No            No          93826.63    No
# 4         Yes           Yes          79084.10    No

# %% [markdown]
# 4. Check null values in the dataset

# %%
#4
df.isnull().sum()
# Out:
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# 5. Check Duplicated

# %%
#5
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 6. How many people have French 'fr' as their Language?

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
df[df['country'] =='France']
# Out:
#       credit_score country  gender  age  tenure    balance  products_number  \
# 0              619  France  Female   42       2       0.00                1
# 2              502  France  Female   42       8  159660.80                3
# 3              699  France  Female   39       1       0.00                2
# 6              822  France    Male   50       7       0.00                2
# 8              501  France    Male   44       4  142051.07                2
# ...            ...     ...     ...  ...     ...        ...              ...
# 9994           800  France  Female   29       2       0.00                2
# 9995           771  France    Male   39       5       0.00                2
# 9996           516  France    Male   35      10   57369.61                1
# 9997           709  France  Female   36       7       0.00                1
# 9999           792  France  Female   28       4  130142.79                1
#
#      credit_card active_member  estimated_salary churn
# 0            Yes           Yes         101348.88   Yes
# 2            Yes            No         113931.57   Yes
# 3             No            No          93826.63    No
# 6            Yes           Yes          10062.80    No
# 8             No           Yes          74940.50    No
# ...          ...           ...               ...   ...
# 9994          No            No         167773.55    No
# 9995         Yes            No          96270.64    No
# 9996         Yes           Yes         101699.77    No
# 9997          No           Yes          42085.58   Yes
# 9999         Yes            No          38190.78    No
#
# [5014 rows x 11 columns]

# %%
df['country'].value_counts(sort=False)
# Out:
# country
# France     5014
# Spain      2477
# Germany    2509
# Name: count, dtype: int64

# %% [markdown]
# 7.How many females and males are in our dataset? Which graph can be plotted to represent this variable?

# %%
#7
df['gender'].value_counts()
# Out:
# gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
# we can be use barplot to represent this variable

plt.Figure(figsize=(6,4), dpi = 500)
sns.barplot(x=df['gender'].value_counts().index,y = df['gender'].value_counts().values, width=0.4)
plt.title('Gender Male vs Female')
plt.show()

# %% [markdown]
# 8. a. How many people are older than 30 years?
#
#     b. How many people are younger than 18 years?
#
#     c. How many people are between 19 and 50 years old?
#
#     d. Plot a histogram for a better understanding of this column.

# %%
df.head()
df.dtypes
# Out:
# credit_score          int64
# country              object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# products_number       int64
# credit_card           int64
# active_member         int64
# estimated_salary    float64
# churn                 int64
# dtype: object

# %%
#a. How many people are older than 30 years?
df[df['age']>30]
# print('There are 1641 people')
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1   83807.86                1
# 2              502   France  Female   42       8  159660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9992           726    Spain    Male   36       2       0.00                1
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10   57369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3   75075.31                2
#
#      credit_card active_member  estimated_salary churn
# 0            Yes           Yes         101348.88   Yes
# 1             No           Yes         112542.58    No
# 2            Yes            No         113931.57   Yes
# 3             No            No          93826.63    No
# 4            Yes           Yes          79084.10    No
# ...          ...           ...               ...   ...
# 9992         Yes            No         195192.40    No
# 9995         Yes            No          96270.64    No
# 9996         Yes           Yes         101699.77    No
# 9997          No           Yes          42085.58   Yes
# 9998         Yes            No          92888.52   Yes
#
# [8032 rows x 11 columns]

# %%
#b. How many people are younger than 18 years?

df[df['age']==18]
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 746            844   France    Male   18       2  160980.03                1
# 1619           656   France    Male   18      10  151762.74                1
# 1678           570   France  Female   18       4   82767.42                1
# 2021           716  Germany  Female   18       3  128743.80                1
# 2136           727   France    Male   18       4  133550.67                1
# 2141           674   France    Male   18       7       0.00                2
# 3330           738   France    Male   18       4       0.00                2
# 3512           806    Spain    Male   18       3       0.00                2
# 3517           771    Spain    Male   18       1       0.00                2
# 3686           706   France    Male   18       2  176139.50                2
# 4556           681   France  Female   18       1   98894.39                1
# 4716           646   France    Male   18      10       0.00                2
# 7334           616   France    Male   18       6       0.00                2
# 7722           684  Germany    Male   18       9   90544.00                1
# 8522           644    Spain    Male   18       8       0.00                2
# 9029           594  Germany    Male   18       1  132694.73                1
# 9501           835  Germany    Male   18       2  142872.36                1
# 9520           727  Germany  Female   18       2   93816.70                2
# 9526           642  Germany    Male   18       5  111183.53                2
# 9572           644    Spain    Male   18       7       0.00                1
# 9782           509   France    Male   18       7  102983.91                1
# 9932           677    Spain    Male   18       8  134796.87                2
#
#      credit_card active_member  estimated_salary churn
# 746           No            No         145936.28    No
# 1619          No           Yes         127014.32    No
# 1678         Yes            No          71811.90    No
# 2021          No            No         197322.13    No
# 2136         Yes           Yes          46941.41    No
# 2141         Yes           Yes          55753.12   Yes
# 3330         Yes           Yes          47799.15    No
# 3512         Yes           Yes          86994.54    No
# 3517          No            No          41542.95    No
# 3686         Yes            No         129654.22    No
# 4556         Yes           Yes           9596.40    No
# 4716          No           Yes          52795.15    No
# 7334         Yes           Yes          27308.58    No
# 7722          No           Yes           4777.23    No
# 8522         Yes            No          59172.42    No
# 9029         Yes            No         167689.56    No
# 9501         Yes           Yes         117632.63    No
# 9520         Yes            No         126172.11    No
# 9526          No           Yes          10063.75    No
# 9572          No           Yes          59645.24   Yes
# 9782         Yes            No         171770.58    No
# 9932         Yes           Yes         114858.90    No

# %%
#c. How many people are between 19 and 50 years old?
df[(df['age']>=19 ) & (df['age']<=50)]
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1   83807.86                1
# 2              502   France  Female   42       8  159660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10   57369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3   75075.31                2
# 9999           792   France  Female   28       4  130142.79                1
#
#      credit_card active_member  estimated_salary churn
# 0            Yes           Yes         101348.88   Yes
# 1             No           Yes         112542.58    No
# 2            Yes            No         113931.57   Yes
# 3             No            No          93826.63    No
# 4            Yes           Yes          79084.10    No
# ...          ...           ...               ...   ...
# 9995         Yes            No          96270.64    No
# 9996         Yes           Yes         101699.77    No
# 9997          No           Yes          42085.58   Yes
# 9998         Yes            No          92888.52   Yes
# 9999         Yes            No          38190.78    No
#
# [8717 rows x 11 columns]

# %%
#d. Plot a histogram for a better understanding of this column.

fig, ax = plt.subplots(figsize=(16,10))
sns.histplot(df['age'])
ax.set_xticks(np.arange(18,90,2))
plt.ylabel('Variable count')
plt.title('AGE')
plt.show()

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#   credit_card active_member  estimated_salary churn
# 0         Yes           Yes         101348.88   Yes
# 1          No           Yes         112542.58    No
# 2         Yes            No         113931.57   Yes
# 3          No            No          93826.63    No
# 4         Yes           Yes          79084.10    No

# %%
df[df['churn']=='Yes']['age']
# Out:
# 0       42
# 2       42
# 5       44
# 7       29
# 16      58
#         ..
# 9981    42
# 9982    46
# 9991    53
# 9997    36
# 9998    42
# Name: age, Length: 2037, dtype: int64

# %%
bins = 50
fig, ax = plt.subplots(1, 2, figsize = (16, 8), dpi = 300)
sns.histplot(df['age'], ax = ax[0], label = 'Distribution of Age', bins = bins)
sns.histplot(df[df['churn']=='Yes']['age'], ax = ax[0], color = 'r', label = 'Distribution of age with churn', bins= bins)
ax[0].set_title('Age with age churn')
ax[0].set_xticks(np.arange(18,90,5))
ax[0].set_yticks(np.arange(0,1100,100))
# ax[0].legend()
ax[1].set_title('Age with age not churn')
sns.histplot(df['age'], ax = ax[1], label = 'Distribution of Age', bins = bins)
sns.histplot(df[df['churn']=='No']['age'], ax = ax[1],  label = 'Distribution of age with not churn', bins = bins)
ax[1].set_xticks(np.arange(18,90,5))
ax[1].set_yticks(np.arange(0,1100,100))

# ax[1].legend()

for i in ax:
    i.legend()
    
for i in ax:
    i.spines[['top', 'right']].set_visible(False)
# ax[1].spines[['top',
#              'right']].set_visible(False)
plt.show()

# %%
df[(df['age']>=53) & (df['age']<=56)]['churn'].value_counts()
# Out:
# churn
# Yes    189
# No     121
# Name: count, dtype: int64

# %% [markdown]
# 9. a. How many customers have a credit card?
#
#     b. Use a countplot to visualize the number of customers with and without a credit card, categorized by churn status.

# %%
df['credit_card'].value_counts()
# Out:
# credit_card
# Yes    7055
# No     2945
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
#a. How many customers have a credit card?
df['credit_card'].value_counts()
# print ('There are 7055 have credit_card')
# Out:
# credit_card
# 1    7055
# 0    2945
# Name: count, dtype: int64

# %%
#b. Use a countplot to visualize the number of customers with and without a credit card, categorized by churn status.

fig, ax = plt.subplots(figsize = (16, 8))
sns.countplot(data = df, x=df['credit_card'], hue = df['churn'])
plt.show()

# %% [markdown]
# 10. a. How many customers are active members?
#
#     b. Use a countplot to visualize the number of customers who are active members and those who are not, categorized by churn status.

# %%
#a. How many customers are active members?
df['active_member'].value_counts()
# Out:
# active_member
# Yes    5151
# No     4849
# Name: count, dtype: int64

# %%
df['active_member']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    0
# 9999    0
# Name: active_member, Length: 10000, dtype: int64

# %%
# b. Use a countplot to visualize the number of customers who are active members and those who are not, categorized by churn status.
fig, ax = plt.subplots(figsize = (16, 8))
sns.countplot(data = df, x=df['active_member'], hue = df['churn'])
plt.show()

# %% [markdown]
# 11. a. Plot a histogram of the column 'Estimated Salary'.
#
#     b. Plot a histogram of customer churn and non-churn.
#
#     c. Compare graph (histogram) Not Churn and churn with all customers.

# %%
#a. Plot a histogram of the column 'Estimated Salary'.
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
#c.b. Compare graph (histogram) Not Churn and churn with all customers.
bins = 50
fig, ax = plt.subplots(1, 2, figsize = (20, 8))
sns.histplot(df['estimated_salary'], ax = ax[0], label = 'Distribution of estimated_salary', bins = bins)
sns.histplot(df[df['churn']=='Yes']['estimated_salary'], ax = ax[0], color = 'r', label = 'Distribution of estimated_salary with churn', bins= bins)
ax[0].set_title('estimated_salary with estimated_salary churn')
# ax[0].set_xticks(np.arange(18,90,5))
# ax[0].set_yticks(np.arange(0,1100,100))
# ax[0].legend()
ax[1].set_title('estimated_salary with estimated_salary not churn')
sns.histplot(df['estimated_salary'], ax = ax[1], label = 'Distribution of estimated_salary', bins = bins)
sns.histplot(df[df['churn']=='No']['estimated_salary'], ax = ax[1],  label = 'Distribution of estimated_salary with not churn', bins = bins)
# ax[1].set_xticks(np.arange(18,90,5))
# ax[1].set_yticks(np.arange(0,1100,100))

# ax[1].legend()

for i in ax:
    i.legend()
    
for i in ax:
    i.spines[['top', 'right']].set_visible(False)
# ax[1].spines[['top',
#              'right']].set_visible(False)
fig.savefig('estimated_salary.png', dpi = 1000)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 8))
sns.histplot(df['estimated_salary'], bins = 50)
ax.set_xticks(np.arange(0, 210000, 10000))
ax.set_yticks(np.arange(1,300,50))
plt.show()

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
#b. Plot a histogram of customer churn and non-churn.
fig, ax = plt.subplots(figsize = (16, 4))
sns.histplot(df['churn'])
ax.set_xticks(np.arange(0,3))
ax.set_yticks(np.arange(1,8000,500))
plt.show()

# %%
df.columns
# Out:
# Index(['credit_score', 'country', 'gender', 'age', 'tenure', 'balance',
#        'products_number', 'credit_card', 'active_member', 'estimated_salary',
#        'churn'],
#       dtype='object')

# %%
#c. Compare graph (histogram) Not Churn and churn with all customers.
fig, ax = plt.subplots(1, 3, figsize = (16, 4))
sns.histplot(df['estimated_salary'], label = ' Distribution of estimated_salary', ax = ax[0])
sns.histplot(df[df['churn']==1]['estimated_salary'] , label = 'Churn Yes with Estimated_salary', ax = ax[1], color = 'r')
sns.histplot(df[df['churn']==0]['estimated_salary'] , label = 'Churn No with Estimated_salary', color = 'b', ax = ax[2])
ax[0].legend()
ax[1].legend()
ax[2].legend()
plt.show()

# %%
df['churn'].value_counts().index
# Out:
# Index([0, 1], dtype='int64', name='churn')

# %%
# plt.pie(df['churn'].value_counts().values)
# plt.show() 
mylabels = df['churn'].value_counts().index

fig, ax = plt.subplots(figsize = (16, 4))
plt.pie(df['churn'].value_counts(),labels = mylabels)
plt.title('Churned VS Not Churned')
plt.legend()
plt.show()

# %% [markdown]
# <a id="section4"></a>
# # Data Visualization :

# %% [markdown]
# ![image.png](attachment:image.png)
