# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#CA6F1E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#283747'></span>"Predcting House Prices." </div>

# %% [markdown]
# <hr>
# <img src="https://i.imgur.com/kCNAFTN.jpg?1" title="source: imgur.com" />

# %% [markdown]
# ### Data Description

# %% [markdown]
# - id:  Unique ID for each home sold
# - date: Date of the home sale
# - price: Price of each home sold
# - bedrooms: Number of bedrooms
# - bathrooms: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# - sqft_living: Square footage of the apartments interior living space
# - sqft_lot: Square footage of the land space
# - floors: Number of floors
# - waterfront: A dummy variable for whether the apartment was overlooking the waterfront or not
# - view: An index from 0 to 4 of how good the view of the property was
# - condition: An index from 1 to 5 on the condition of the apartment,
# - grade: An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# - sqft_above: The square footage of the interior housing space that is above ground level
# - sqft_basement: The square footage of the interior housing space that is below ground level
# - yr_built: The year the house was initially built
# - yr_renovated: The year of the house’s last renovation
# - zipcode: What zipcode area the house is in
# - lat: Lattitude
# - long: Longitude
# - sqft_living15: The square footage of interior housing living space for the nearest 15 neighbors
# - sqft_lot15: The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# - [1. Exploring The Dataset](#1)
#     - [1.1 Load The Datset](#1.1)
#     - [1.2 Data Cleaning](#1.3)
#         - [1..1 Missing Value](#1.3.1)

# %% [markdown]
# <a id="a"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#222222;
#             overflow:hidden;
#             font-weight:700">1 <span style='color:#CDA63A'>|</span>Exploring The Dataset</div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# <a id="1.1"></a>
# ## <b>1.1 <span style='color:#00008B'>Load The dataset</span></b>

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
df.drop(columns='id', inplace=True)

# %%
df
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 1      20141209T000000  538000.0         3       2.25         2570      7242
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 3      20141209T000000  604000.0         4       3.00         1960      5000
# 4      20150218T000000  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0         3       2.50         1530      1131
# 21609  20150223T000000  400000.0         4       2.50         2310      5813
# 21610  20140623T000000  402101.0         2       0.75         1020      1350
# 21611  20150116T000000  400000.0         3       2.50         1600      2388
# 21612  20141015T000000  325000.0         2       0.75         1020      1076
#
# ...

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[df['price']<=3*(10**5)]
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 6      20140627T000000  257500.0         3       2.25         1715      6819
# 7      20150115T000000  291850.0         3       1.50         1060      9711
# 8      20150415T000000  229500.0         3       1.00         1780      7470
# ...                ...       ...       ...        ...          ...       ...
# 21526  20150428T000000  290000.0         3       2.25         1610      3764
# 21550  20140729T000000  249000.0         3       2.00         1260      1125
# 21572  20140707T000000  230000.0         3       1.75         1140      1201
# 21585  20140828T000000  270000.0         3       2.50         1870      5000
# 21602  20140626T000000  224000.0         3       1.75         1500     11968
#
# ...

# %%
df[df['price']>=2*(10**6)]
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21     20140826T000000  2000000.0         3       2.75         3050     44867
# 153    20150401T000000  2250000.0         4       3.25         5180     19850
# 246    20140929T000000  2400000.0         4       2.50         3650      8354
# 269    20150504T000000  2900000.0         4       3.25         5050     20100
# 282    20150513T000000  2050000.0         5       3.00         3830      8480
# ...                ...        ...       ...        ...          ...       ...
# 21310  20140703T000000  2351960.0         4       4.25         5010     19412
# 21368  20140630T000000  2065000.0         4       3.75         4350      7965
# 21506  20140509T000000  2238890.0         5       6.50         7270    130017
# 21530  20150407T000000  3000000.0         4       3.75         5090     14823
# 21576  20150107T000000  3567000.0         5       4.50         4850     10584
#
# ...

# %%
# bins = 50
# fig, ax = plt.subplots(1, 2, figsize = (20, 8))
# sns.histplot(df['estimated_salary'], ax = ax[0], label = 'Distribution of estimated_salary', bins = bins)
# sns.histplot(df[df['churn']=='Yes']['estimated_salary'], ax = ax[0], color = 'r', label = 'Distribution of estimated_salary with churn', bins= bins)
# ax[0].set_title('estimated_salary with estimated_salary churn')
# # ax[0].set_xticks(np.arange(18,90,5))
# # ax[0].set_yticks(np.arange(0,1100,100))
# # ax[0].legend()
# ax[1].set_title('estimated_salary with estimated_salary not churn')
# sns.histplot(df['estimated_salary'], ax = ax[1], label = 'Distribution of estimated_salary', bins = bins)
# sns.histplot(df[df['churn']=='No']['estimated_salary'], ax = ax[1],  label = 'Distribution of estimated_salary with not churn', bins = bins)
# # ax[1].set_xticks(np.arange(18,90,5))
# # ax[1].set_yticks(np.arange(0,1100,100))

# # ax[1].legend()

# for i in ax:
#     i.legend()
    
# for i in ax:
#     i.spines[['top', 'right']].set_visible(False)
# # ax[1].spines[['top',
# #              'right']].set_visible(False)
# fig.savefig('estimated_salary.png', dpi = 1000)
# plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 8))
sns.histplot(df['price'])

ax.set_xticks(np.arange(7*(10**4), 8.1*(10**(6)), 0.5*(10**6)))
ax.set_yticks(np.arange(0,1300,100))
plt.show()

# %%
df['sqft_lot'].describe()
# Out:
# count    2.161300e+04
# mean     1.510697e+04
# std      4.142051e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068800e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %%
df[df['sqft_lot']>20000].index
# Out:
# Index([    5,    21,    36,    41,    49,    60,    69,    70,    74,    75,
#        ...
#        21431, 21470, 21484, 21485, 21486, 21494, 21506, 21520, 21525, 21548],
#       dtype='int64', length=2312)

# %%
df.drop(index = df[df['sqft_lot']>20000].index, inplace=True)

# %%
fig, ax = plt.subplots(figsize = (16, 8))
sns.histplot(df['sqft_lot'])
# sns.histplot(df[df['price']>=2*(10**6)]['sqft_lot'], bins = 100)
# sns.histplot(df[df['price']<=3*(10**5)]['sqft_lot'])
# sns.histplot(df[(df['price']>=3*(10**5)) & (df['price']<=2*(10**6))]['sqft_lot'])
# ax.set_xticks(np.arange(250, 14000, 1000))
# ax.set_yticks(np.arange(0,1300,100))
plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 8))
sns.histplot(df['sqft_living'])
sns.histplot(df[df['price']>=2*(10**6)]['sqft_living'], bins = 100)
sns.histplot(df[df['price']<=3*(10**5)]['sqft_living'])
sns.histplot(df[(df['price']>=3*(10**5)) & (df['price']<=2*(10**6))]['sqft_living'])
ax.set_xticks(np.arange(250, 14000, 1000))
# ax.set_yticks(np.arange(0,1300,100))
plt.show()

# %%
df['price'].describe()

# %%
sns.boxplot(df['price'])
