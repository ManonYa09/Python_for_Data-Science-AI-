# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#CA6F1E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#283747'></span>"Predicting Insurance Charges." </div>

# %% [markdown]
# Develop a model to predict the insurance charges (**charges**). This model can help the insurance company in setting premiums more accurately.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Load and uderstanding the dataset
#
# **Objective:** Familiarize yourself with the dataset's structure and the type of information it contains.
#
#     Tasks:
#     - Identify the variables and their data types.
#     - Determine the number of entries in the dataset.
#     - Check for missing values.

# %% [markdown]
# ### 2. Exploratory Data Analysis (EDA)
#
# #### 1.2 Data Cleaning

# %% [markdown]
# Objective: Ensure the dataset is prepared for analysis.
#
# Tasks:
#
# Confirm there are no missing values, or handle them if present.

# %% [markdown]
# ![image.png](attachment:548edbb8-f892-4500-9d90-2472c2d9de41.png)

# %% [markdown]
# ### Objective: Explore the dataset to uncover initial insights, patterns, and distributions.
#
# Tasks:
#
# - Analyze the distribution of age, BMI, and insurance charges using histograms.
#
# - Visualize the distribution of categorical variables (sex, smoker, region) using bar charts.
#
# - Explore the relationship between BMI and insurance charges with scatter plots.
# - Explore the relationship between age and insurance charges with scatter plots.
#
# - Investigate the impact of smoking status on insurance charges.

# %% [markdown]
# #### In-depth Analysis
#
# Objective: Conduct specific, deeper analyses to answer more complex questions.
#
# Tasks:
#
# - Compare the average insurance charges across different regions.
#
# - Analyze the impact of the number of children on insurance charges.
#
# - Explore how age and smoking status together influence insurance charges.
#
# - Examine the relationship between BMI categories (Underweight, Normal, Overweight, Obese) and insurance charges.

# %% [markdown]
# ### Reporting and Insights
# Objective: Summarize findings and extract actionable insights from the analyses.
#
# Tasks:
#
# - Write a comprehensive report detailing the exploratory data analysis and in-depth analysis findings.
#
# - Highlight significant patterns, trends, and relationships found in the data.
# - Provide recommendations for individuals looking to lower their insurance charges based on the analysis.
